# %% [markdown]
# # GNN4DM: A Graph Neural Network-based method to identify overlapping functional disease modules
#
# This is the original implementation of GNN4DM, a graph neural network-based structured model that automates the discovery of overlapping functional disease modules. GNN4DM effectively integrates network topology with genomic data to learn the representations of the genes corresponding to functional modules and align these with known biological pathways for enhanced interpretability.

# %% [markdown]
# First, we import the necessary libraries.

# %%
import torch
import torch_geometric
import networkx as nx
import pandas as pd
import numpy as np
import scipy as sp

from sklearn.model_selection import ParameterSampler

from models import *
from data import *
from utils import *

import statistics

from cdlib import evaluation

from torch.utils.tensorboard import SummaryWriter

print( f"PyTorch version: {torch.__version__}" )
print( f"CUDA version: {torch.version.cuda}" )
print( f"PyG version: {torch_geometric.__version__}" )
print( f"NetworkX version: {nx.__version__}" )

# %% [markdown]
# Second, we import graph from STRING, read input features from GTEx, GWAS Atlas, and compute centrality measures (as additional input features).
# Besides, we import the output features (used as auxiliary prediction tasks) from MSigDB.

# %%
inputFeatures = ['GTEx','GWASAtlas_nonukb_512','centrality_measures']
outputFeatures = ['kegg','reactome','wikipathways','biocarta','pid']

dataset = get_STRING_dataset( inputFeatures = inputFeatures, outputFeatures = outputFeatures )

show_dataset( dataset )

data = dataset['data']
G = dataset['graph']

# %% [markdown]
# Send data to cuda, if available.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = torch.device(device)
print(device)

data = data.to(device)

# %% [markdown]
# Define training and validation functions.

# %%
def train( model, data, source_edge_index, pos_edge_index, neg_edge_index, lambda_bce_loss, lambda_l1_positives_loss, lambda_l2_positives_loss, optimizer, writer, iter = None):
    model.train()
    optimizer.zero_grad()

    # compute node embeddings with the encoder       
    F, y_preds = model.encode( data.x, data.edge_index )
    # compute link strength with the decoder for the positive and the negative edges, respectively
    H_positive = model.decode( F, source_edge_index, pos_edge_index )
    H_negative = model.decode( F, source_edge_index, neg_edge_index )
    # compute loss
    ## Bernoulli-Poisson loss
    bp_loss = model.nll_BernoulliPoisson_loss( H_positive, H_negative )
    ## Binary cross-entropy losses for all datasets
    bce_losses = dict()
    for key in y_preds:
        if data.train_indices[key].dim() == 1:
            bce_losses[key] = model.bce_loss( y_preds[key][data.train_indices[key],:], data.ys[key][data.train_indices[key],:] )
        else:
            bce_losses[key] = model.bce_loss( y_preds[key][data.train_indices[key]], data.ys[key][data.train_indices[key]] )
    # bce_losses = { key : model.bce_lprint( "\n", results )oss( y_preds[key][data.train_indices[key]], data.ys[key][data.train_indices[key]] ) for key in y_preds }
    ## GCN L1 and L2 losses
    l1_loss_gcn, l2_loss_gcn = model.gcn_l1_l2_losses()
    ## 
    l1_positives_loss, l2_positives_loss = model.output_models_l1_l2_losses()
    ## compute final loss
    loss = bp_loss
    for bce_loss in bce_losses.values():
        loss += lambda_bce_loss * bce_loss
    loss += 0.0 * l1_loss_gcn
    loss += 0.0 * l2_loss_gcn
    loss += lambda_l1_positives_loss * l1_positives_loss
    loss += lambda_l2_positives_loss * l2_positives_loss
 
    if iter != None:
        writer.add_scalar('train/loss', loss.item(), iter)
        writer.add_scalar('train/bernoulli_poisson_loss', bp_loss, iter)
        for key, bce_loss in bce_losses.items():
            writer.add_scalar(f"train/bce_loss_{key}", bce_loss, iter)
        writer.add_scalar('train/l1_loss_gcn', l1_loss_gcn, iter)
        writer.add_scalar('train/l2_loss_gcn', l2_loss_gcn, iter)
        writer.add_scalar('train/l1_positives_loss', l1_positives_loss, iter)
        writer.add_scalar('train/l2_positives_loss', l2_positives_loss, iter)

    loss.backward(retain_graph=True)
    optimizer.step()

    return

@torch.no_grad()
def test(model, data, G : nx.Graph, writer=None, iter=None):
    model.eval()

    # compute node embeddings with the encoder       
    F, y_preds = model.encode( data.x, data.edge_index )

    internal_evaluation_scores = {}

    # compute BCE loss in validation sets of pathway DBs
    # bce_losses = { key : model.bce_loss( y_preds[key][data.valid_indices[key]], data.ys[key][data.valid_indices[key]] ) for key in y_preds }
    bce_losses = dict()
    for key in y_preds:
        if data.valid_indices[key].dim() == 1:
            bce_losses[key] = model.bce_loss( y_preds[key][data.valid_indices[key],:], data.ys[key][data.valid_indices[key],:] )
        else:
            bce_losses[key] = model.bce_loss( y_preds[key][data.valid_indices[key]], data.ys[key][data.valid_indices[key]] )
    # sum losses, and write them into the output
    valid_bce_loss = 0.0
    for key, bce_loss in bce_losses.items():
        internal_evaluation_scores[f"bce_loss_{key}"] = bce_loss.item()
        valid_bce_loss += bce_loss.item()
    internal_evaluation_scores["sum_bce_loss"] = valid_bce_loss

    # compute accuracy and F1 score in validation sets of pathway DBs
    accuracies, sensitivities, specificities, precisions, f1_scores, auprcs = calculateMetrics( y_preds, data.ys, data.valid_indices )
    for key in accuracies:
        internal_evaluation_scores[f"accuracy_{key}"] = accuracies[key]
        internal_evaluation_scores[f"sensitivity_{key}"] = sensitivities[key]
        internal_evaluation_scores[f"specificity_{key}"] = specificities[key]
        internal_evaluation_scores[f"precision_{key}"] = precisions[key]
        internal_evaluation_scores[f"f1_score_{key}"] = f1_scores[key]
        internal_evaluation_scores[f"auprc_{key}"] = auprcs[key]
    internal_evaluation_scores["mean_accuracy"] = statistics.mean(accuracies.values())
    internal_evaluation_scores["mean_sensitivity"] = statistics.mean(sensitivities.values())
    internal_evaluation_scores["mean_specificity"] = statistics.mean(specificities.values())
    internal_evaluation_scores["mean_precision"] = statistics.mean(precisions.values())
    internal_evaluation_scores["mean_f1_score"] = statistics.mean(f1_scores.values())
    internal_evaluation_scores["mean_auprc"] = statistics.mean(auprcs.values())

    cosine_self_similarity_loss = model.cosine_similarity_loss( F, type = 'l2', min_threshold = 0.1 )
    internal_evaluation_scores["cosine_self_similarity_loss"] = cosine_self_similarity_loss.item()

    rmse_of_module_size_loss = model.rmse_of_module_size_loss( F = F, threshold = model.getThresholdOfCommunities(), expected_mean = 50.0 )
    internal_evaluation_scores["rmse_of_module_size_loss"] = rmse_of_module_size_loss.item()

    internal_evaluation_scores["thresholdOfCommunities"] = model.getThresholdOfCommunities().item()

    # get predicted communities
    pred_communities, original_communities = getPredictecCommunities3( F, G, threshold = model.getThresholdOfCommunities(), normalize=False )
    # and evaluate them
    if pred_communities.communities != []:
        internal_evaluation_scores['count'] = len(pred_communities.communities)
        internal_evaluation_scores['average_size'] = pred_communities.size().score
        internal_evaluation_scores['max_size'] = np.max(pred_communities.size(summary=False))
        internal_evaluation_scores['num_smaller_5'] = np.sum(np.array(pred_communities.size(summary=False)) <= 5)
        internal_evaluation_scores['num_smaller_10'] = np.sum(np.array(pred_communities.size(summary=False)) <= 10)
        internal_evaluation_scores['num_smaller_50'] = np.sum(np.array(pred_communities.size(summary=False)) <= 50)
        internal_evaluation_scores['num_smaller_100'] = np.sum(np.array(pred_communities.size(summary=False)) <= 100)
        internal_evaluation_scores['num_smaller_200'] = np.sum(np.array(pred_communities.size(summary=False)) <= 200)
        internal_evaluation_scores['node_coverage'] = pred_communities.node_coverage
        internal_evaluation_scores['mean_module_per_node'] = (F >= model.getThresholdOfCommunities()).sum(dim=1).float().mean().item()
        internal_evaluation_scores['average_internal_degree'] = pred_communities.average_internal_degree().score
        internal_evaluation_scores['conductance'] = pred_communities.conductance().score
        internal_evaluation_scores['internal_edge_density'] = pred_communities.internal_edge_density().score
        internal_evaluation_scores['fraction_over_median_degree'] = pred_communities.fraction_over_median_degree().score
        # internal_evaluation_scores['avg_embeddedness'] = pred_communities.avg_embeddedness().score # it takes ages to compute
        # internal_evaluation_scores['modularity_overlap'] = pred_communities.modularity_overlap().score # it takes ages to compute

        if 'groundtruth_communities' in dataset:
            internal_evaluation_scores['onmi'] = evaluation.overlapping_normalized_mutual_information_MGH( dataset['groundtruth_communities'], pred_communities ).score

        if iter != None:
            for key,value in internal_evaluation_scores.items():
                writer.add_scalar(f"test/{key}", value, iter)
                
    if 'groundtruth_communities' in dataset:
        pred_communities_max = getPredictecCommunities2( F, G, threshold = None )

        if pred_communities_max.communities != []:
            internal_evaluation_scores['nmi_max'] = evaluation.overlapping_normalized_mutual_information_MGH( dataset['groundtruth_communities'], pred_communities_max ).score
            
            if iter != None:
                writer.add_scalar('test/nmi_max', internal_evaluation_scores['nmi_max'], iter)
            
    return internal_evaluation_scores, pred_communities, original_communities

# %% [markdown]
# Define hyper-parameters.

# %%
rng = np.random.RandomState(65)

param_grid = { 'learning_rate': [0.001], 
                 'learning_rate_decay_step_size' : [250],
                 'weight_decay': [0.0],
                 'hidden_channels_before_module_representation': [128],                   
                 'module_representation_length': [500,600,700,800,900,1000], 
                 'threshold': ['auto'], # 0.25,0.5,0.75,1.0,'auto'
                 'batchnorm' : [True],  
                 'dropout': [0.0],
                 'lambda_bce_loss': [10.0],
                 'lambda_l1_positives_loss': [0.0],
                 'lambda_l2_positives_loss': [0.0],
                 'model_type' : ["GCN"],
                 'model_output' : ['kegg|reactome|wikipathways|biocarta'], #
                 'transform_probability_method' : ['tanh'] }

 
param_list = list(ParameterSampler( param_grid, n_iter=4, random_state=rng))

# %% [markdown]
# Finally, train and validate the models.

# %%
epochs = 5000
eval_steps = 50

batch_index = 0
run_index = 0


final_results = list()

for params in param_list:

    output_models = {}
    for db in params['model_output'].split('|'):
        if db in dataset['msigdb_term_ids']:
            output_models[db] = PositiveLinear( in_features = params['module_representation_length'], 
                                                out_features = len(dataset['msigdb_term_ids'][db]), 
                                                ids = dataset['msigdb_term_ids'][db] ).to(device)

    model = GAEL( encoder = GNN( in_channels = data.num_features, 
                                 hidden_channels_before_module_representation = [params['hidden_channels_before_module_representation']], 
                                 module_representation_channels = params['module_representation_length'], 
                                 out_models = output_models, 
                                 dropout = params['dropout'], 
                                 batchnorm = params['batchnorm'], 
                                 transform_probability_method = params['transform_probability_method'],
                                 threshold = params['threshold'],
                                 type = params['model_type'] ),
                  decoder = InnerProductDecoder() ).to(device)

    print(model)

    total_params = sum(p.numel() for p in model.parameters())
    print("Total number of parameters:", total_params)

    try:      
        writer = SummaryWriter(f"runs/{G.name}/batch_{batch_index}/{model.name}_bce{params['lambda_bce_loss']}_{run_index:03d}")

        optimizer, scheduler = model.configure_optimizers( params )
        model.reset_parameters()

        iter = 1
        # start training
        for epoch in range(1, 1 + epochs):

            source_edge_index, pos_edge_index, neg_edge_index = torch_geometric.utils.structured_negative_sampling( edge_index = data.edge_index )

            # Generate a random permutation index
            num_samples = len(source_edge_index)
            perm = torch.randperm(num_samples)

            # Apply the permutation index to all three lists
            source_edge_index = source_edge_index[perm]
            pos_edge_index = pos_edge_index[perm]
            neg_edge_index = neg_edge_index[perm]

            # Divide each shuffled list into ten (approximately) equal parts
            num_parts = 10
            part_size = num_samples // num_parts

            for i in range(num_parts):
                start_idx = i * part_size
                end_idx = (i + 1) * part_size

                # Adjust the end index for the last part
                if i == num_parts - 1:
                    end_idx = num_samples

                source_part = source_edge_index[start_idx:end_idx]
                pos_part = pos_edge_index[start_idx:end_idx]
                neg_part = neg_edge_index[start_idx:end_idx]

                # training step
                train( model, data, source_part, pos_part, neg_part, 
                       lambda_bce_loss = params['lambda_bce_loss'], 
                       lambda_l1_positives_loss = params['lambda_l1_positives_loss'], lambda_l2_positives_loss = params['lambda_l2_positives_loss'], 
                       optimizer = optimizer, writer = writer, iter = iter )
                iter += 1

            # validation
            if epoch % eval_steps == 0:
                valid_results, pred_communities, original_communities = test( model, data, G, writer = writer, iter = epoch )

                results = {'epoch': epoch, **valid_results}

                print( "\n", results )

                # export results
                filename = f"./runs/{G.name}/batch_{batch_index}/{model.name}_bce{params['lambda_bce_loss']}_{run_index:03d}/modules_{epoch:05d}.json"
                saveResultsToJSON( valid_results, original_communities, filename, dataset['node_index_dict'] )

                # save model
                modelfilename = f"./runs/{G.name}/batch_{batch_index}/{model.name}_bce{params['lambda_bce_loss']}_{run_index:03d}/model_{epoch:05d}.pt"
                torch.save(model.state_dict(), modelfilename)

                # export weights of final model layers
                ws, ids = [], []
                for name in model.encoder.output_models:
                    ws.append( model.encoder.output_models[name].weight.cpu().detach().numpy().T )
                    ids.extend( model.encoder.output_models[name].id_list )

                weightfilename = f"./runs/{G.name}/batch_{batch_index}/{model.name}_bce{params['lambda_bce_loss']}_{run_index:03d}/weights_{epoch:05d}.csv"
                df_w = pd.DataFrame( data = np.hstack(ws), columns=ids)
                df_w.to_csv( weightfilename )
                
                final_results.append( { 'model': str(model), 'model-name': model.name, **params, 'epoch': epoch, 'run': run_index, **valid_results } )

                df = pd.DataFrame( final_results )
                df.to_csv( f'randomsearch_results{batch_index}_{G.name}.csv' )

            # apply learning rate scheduler
            scheduler.step()

        df = pd.DataFrame( final_results )
        df.to_csv( f'randomsearch_results{batch_index}_{G.name}.csv' )

        del model
        torch.cuda.empty_cache()

        run_index += 1

    except BaseException as error:
        print( model )
        print('An exception occurred: {}'.format(error))

        del model
        torch.cuda.empty_cache()
# Out:
# GAEL( Encoder: GCNConv(571, 128); ReLU; BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True); GCNConv(128, 800); SoftPlus; {PositiveLinear(in_features=800, out_features=186, bias=True)|PositiveLinear(in_features=800, out_features=1288, bias=True)|PositiveLinear(in_features=800, out_features=621, bias=True)|PositiveLinear(in_features=800, out_features=221, bias=True)}, Decoder: InnerProductDecoder )
# An exception occurred:
# GAEL( Encoder: GCNConv(571, 128); ReLU; BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True); GCNConv(128, 900); SoftPlus; {PositiveLinear(in_features=900, out_features=186, bias=True)|PositiveLinear(in_features=900, out_features=1288, bias=True)|PositiveLinear(in_features=900, out_features=621, bias=True)|PositiveLinear(in_features=900, out_features=221, bias=True)}, Decoder: InnerProductDecoder )
# Total number of parameters: 2276289
# decay: {'encoder.conv_last.lin.weight', 'encoder.output_models.kegg.weight', 'encoder.output_models.biocarta.weight', 'encoder.output_models.reactome.weight', 'encoder.output_models.wikipathways.weight', 'encoder.convs.0.lin.weight'}
# no_decay: {'encoder.output_models.reactome.bias', 'encoder.batchnorms_convs.0.bias', 'encoder.batchnorms_convs.0.weight', 'encoder.output_models.biocarta.bias', 'encoder.output_models.kegg.bias', 'encoder.conv_last.bias', 'encoder.convs.0.bias', 'encoder.output_models.wikipathways.bias', 'encoder.threshold'}
#
#  {'epoch': 50, 'bce_loss_kegg': 0.5060439109802246, 'bce_loss_reactome': 0.5032109022140503, 'bce_loss_wikipathways': 0.5040061473846436, 'bce_loss_biocarta': 0.5048577785491943, 'sum_bce_loss': 2.018118739128113, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.5030983436692507, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.5013211929147278, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.5014320995021403, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.5038230259730992, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.5024186655148045, 'cosine_self_similarity_loss': 768.6151123046875, 'rmse_of_module_size_loss': 186.1464080810547, 'thresholdOfCommunities': 0.5578573346138, 'count': 900, 'average_size': 26.35333333333333, 'max_size': 5545, 'num_smaller_5': 7, 'num_smaller_10': 146, 'num_smaller_50': 868, 'num_smaller_100': 895, 'num_smaller_200': 899, 'node_coverage': 0.3905527765465713, 'mean_module_per_node': 1.5018044710159302, 'average_internal_degree': 0.059821211612843164, 'conductance': 0.9980644212455333, 'internal_edge_density': 8.718206234856424e-05, 'fraction_over_median_degree': 0.0020422315507251368}
#
#  {'epoch': 100, 'bce_loss_kegg': 0.3676290810108185, 'bce_loss_reactome': 0.3630654513835907, 'bce_loss_wikipathways': 0.3637847602367401, 'bce_loss_biocarta': 0.36758819222450256, 'sum_bce_loss': 1.4620674848556519, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.5030983436692507, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.5013211929147278, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.5014320995021403, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.5038230259730992, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.5024186655148045, 'cosine_self_similarity_loss': 770.7147827148438, 'rmse_of_module_size_loss': 998.78173828125, 'thresholdOfCommunities': 0.5578573346138, 'count': 41, 'average_size': 158.6341463414634, 'max_size': 6438, 'num_smaller_5': 38, 'num_smaller_10': 40, 'num_smaller_50': 40, 'num_smaller_100': 40, 'num_smaller_200': 40, 'node_coverage': 0.409485214968657, 'mean_module_per_node': 0.41182801127433777, 'average_internal_degree': 1.311784450556528, 'conductance': 0.9617777084953907, 'internal_edge_density': 0.024590243002431893, 'fraction_over_median_degree': 0.012157237136211065}
#
#  {'epoch': 150, 'bce_loss_kegg': 0.2732985317707062, 'bce_loss_reactome': 0.26703643798828125, 'bce_loss_wikipathways': 0.26773446798324585, 'bce_loss_biocarta': 0.27430039644241333, 'sum_bce_loss': 1.0823698341846466, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.5030983436692507, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.5013211929147278, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.5014320995021403, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.5038230259730992, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.5024186655148045, 'cosine_self_similarity_loss': 772.2443237304688, 'rmse_of_module_size_loss': 2958.192138671875, 'thresholdOfCommunities': 0.5578573346138, 'count': 5, 'average_size': 1333.8, 'max_size': 6664, 'num_smaller_5': 4, 'num_smaller_10': 4, 'num_smaller_50': 4, 'num_smaller_100': 4, 'num_smaller_200': 4, 'node_coverage': 0.4222756917621731, 'mean_module_per_node': 0.4222756624221802, 'average_internal_degree': 10.651800720288115, 'conductance': 0.817903456272623, 'internal_edge_density': 0.0015986493651940741, 'fraction_over_median_degree': 0.09789915966386555}
#
#  {'epoch': 200, 'bce_loss_kegg': 0.20865629613399506, 'bce_loss_reactome': 0.20082266628742218, 'bce_loss_wikipathways': 0.20152971148490906, 'bce_loss_biocarta': 0.21054625511169434, 'sum_bce_loss': 0.8215549290180206, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.5030983436692507, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.5013211929147278, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.5014320995021403, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.5038230259730992, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.5024186655148045, 'cosine_self_similarity_loss': 771.3142700195312, 'rmse_of_module_size_loss': 3815.91748046875, 'thresholdOfCommunities': 0.5578573346138, 'count': 3, 'average_size': 2220.3333333333335, 'max_size': 6659, 'num_smaller_5': 2, 'num_smaller_10': 2, 'num_smaller_50': 2, 'num_smaller_100': 2, 'num_smaller_200': 2, 'node_coverage': 0.42176913822579626, 'mean_module_per_node': 0.4217691123485565, 'average_internal_degree': 17.96806327276368, 'conductance': 0.6958173487192395, 'internal_edge_density': 0.0026987178240858636, 'fraction_over_median_degree': 0.16594083195675027}
#
#  {'epoch': 250, 'bce_loss_kegg': 0.16355614364147186, 'bce_loss_reactome': 0.1542958766222, 'bce_loss_wikipathways': 0.155029296875, 'bce_loss_biocarta': 0.166194885969162, 'sum_bce_loss': 0.6390762031078339, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.49529800671116764, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.5013211929147278, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.5014320995021403, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.5038230259730992, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.5004685812752837, 'cosine_self_similarity_loss': 769.8001708984375, 'rmse_of_module_size_loss': 2331.781494140625, 'thresholdOfCommunities': 0.5578573346138, 'count': 8, 'average_size': 831.375, 'max_size': 6644, 'num_smaller_5': 7, 'num_smaller_10': 7, 'num_smaller_50': 7, 'num_smaller_100': 7, 'num_smaller_200': 7, 'node_coverage': 0.4208193503450896, 'mean_module_per_node': 0.42113593220710754, 'average_internal_degree': 6.793497892835641, 'conductance': 0.8857380095285832, 'internal_edge_density': 0.0010226551095642994, 'fraction_over_median_degree': 0.0607126730885009}
#
#  {'epoch': 300, 'bce_loss_kegg': 0.1353318989276886, 'bce_loss_reactome': 0.12496194988489151, 'bce_loss_wikipathways': 0.12572568655014038, 'bce_loss_biocarta': 0.13852454721927643, 'sum_bce_loss': 0.5245440825819969, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.5012791141392658, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.5001381302431405, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.5014320995021403, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.5038230259730992, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.5016680924644115, 'cosine_self_similarity_loss': 768.4635620117188, 'rmse_of_module_size_loss': 3199.25341796875, 'thresholdOfCommunities': 0.5578573346138, 'count': 4, 'average_size': 1614.75, 'max_size': 6448, 'num_smaller_5': 2, 'num_smaller_10': 3, 'num_smaller_50': 3, 'num_smaller_100': 3, 'num_smaller_200': 3, 'node_coverage': 0.408915342240233, 'mean_module_per_node': 0.4089786410331726, 'average_internal_degree': 14.32327853598015, 'conductance': 0.7572659630048516, 'internal_edge_density': 0.06464414123405927, 'fraction_over_median_degree': 0.20748035566583953}
#
#  {'epoch': 350, 'bce_loss_kegg': 0.11355026066303253, 'bce_loss_reactome': 0.1021774560213089, 'bce_loss_wikipathways': 0.1029743179678917, 'bce_loss_biocarta': 0.1172671839594841, 'sum_bce_loss': 0.4359692186117172, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.509259223862534, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.495170985994001, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.5014320995021403, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.4940464092278835, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.4999771796466397, 'cosine_self_similarity_loss': 767.7593994140625, 'rmse_of_module_size_loss': 4424.36328125, 'thresholdOfCommunities': 0.5578542351722717, 'count': 2, 'average_size': 3667.0, 'max_size': 6215, 'num_smaller_5': 0, 'num_smaller_10': 0, 'num_smaller_50': 0, 'num_smaller_100': 0, 'num_smaller_200': 0, 'node_coverage': 0.4611536756790983, 'mean_module_per_node': 0.46438291668891907, 'average_internal_degree': 32.80359374427087, 'conductance': 0.23162830915191346, 'internal_edge_density': 0.00879912703997757, 'fraction_over_median_degree': 0.47907358958154944}
#
#  {'epoch': 400, 'bce_loss_kegg': 0.09684201329946518, 'bce_loss_reactome': 0.08441117405891418, 'bce_loss_wikipathways': 0.0852467268705368, 'bce_loss_biocarta': 0.10091745108366013, 'sum_bce_loss': 0.3674173653125763, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.44716438444357975, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.4961068722075825, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.5014320995021403, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.5038230259730992, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.48713159553160046, 'cosine_self_similarity_loss': 755.600341796875, 'rmse_of_module_size_loss': 2665.434326171875, 'thresholdOfCommunities': 0.5578698515892029, 'count': 5, 'average_size': 1680.6, 'max_size': 5115, 'num_smaller_5': 0, 'num_smaller_10': 1, 'num_smaller_50': 2, 'num_smaller_100': 3, 'num_smaller_200': 3, 'node_coverage': 0.5246628253023491, 'mean_module_per_node': 0.5320711135864258, 'average_internal_degree': 23.30339777191568, 'conductance': 0.2765307445632865, 'internal_edge_density': 0.13101468331415222, 'fraction_over_median_degree': 0.3951526742673213}
#
#  {'epoch': 450, 'bce_loss_kegg': 0.0839277058839798, 'bce_loss_reactome': 0.07050428539514542, 'bce_loss_wikipathways': 0.07137137651443481, 'bce_loss_biocarta': 0.08833563327789307, 'sum_bce_loss': 0.3141390010714531, 'accuracy_kegg': 0.9938223958015442, 'sensitivity_kegg': 0.0, 'specificity_kegg': 1.0, 'precision_kegg': nan, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.4300863390529919, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.48406268350902965, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.497765548161659, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.494233273579477, 'mean_accuracy': 0.9951763600111008, 'mean_sensitivity': 0.0, 'mean_specificity': 1.0, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.47653696107578936, 'cosine_self_similarity_loss': 753.817138671875, 'rmse_of_module_size_loss': 451.4457702636719, 'thresholdOfCommunities': 0.5578471422195435, 'count': 177, 'average_size': 59.909604519774014, 'max_size': 4236, 'num_smaller_5': 173, 'num_smaller_10': 173, 'num_smaller_50': 174, 'num_smaller_100': 174, 'num_smaller_200': 174, 'node_coverage': 0.6292028113721269, 'mean_module_per_node': 0.6714366674423218, 'average_internal_degree': 0.8247990912587193, 'conductance': 0.9570753851962677, 'internal_edge_density': 0.060488334247616064, 'fraction_over_median_degree': 0.011135494149439186}
#
#  {'epoch': 500, 'bce_loss_kegg': 0.07394381612539291, 'bce_loss_reactome': 0.05959516018629074, 'bce_loss_wikipathways': 0.06046762689948082, 'bce_loss_biocarta': 0.07870543748140335, 'sum_bce_loss': 0.2727120406925678, 'accuracy_kegg': 0.9937728047370911, 'sensitivity_kegg': 0.0, 'specificity_kegg': 0.9999500513076782, 'precision_kegg': 0.0, 'f1_score_kegg': 0.0, 'auprc_kegg': 0.43434528381992543, 'accuracy_reactome': 0.9973685145378113, 'sensitivity_reactome': 0.0, 'specificity_reactome': 1.0, 'precision_reactome': nan, 'f1_score_reactome': 0.0, 'auprc_reactome': 0.47084469894704634, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.48687772713289407, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.42002011530125305, 'mean_accuracy': 0.9951639622449875, 'mean_sensitivity': 0.0, 'mean_specificity': 0.9999875128269196, 'mean_precision': nan, 'mean_f1_score': 0.0, 'mean_auprc': 0.45302195630027975, 'cosine_self_similarity_loss': 739.1143188476562, 'rmse_of_module_size_loss': 1111.0909423828125, 'thresholdOfCommunities': 0.5577491521835327, 'count': 26, 'average_size': 383.5769230769231, 'max_size': 3870, 'num_smaller_5': 22, 'num_smaller_10': 22, 'num_smaller_50': 22, 'num_smaller_100': 23, 'num_smaller_200': 23, 'node_coverage': 0.6031786234407649, 'mean_module_per_node': 0.6314822435379028, 'average_internal_degree': 5.241442266619936, 'conductance': 0.7358911557254124, 'internal_edge_density': 0.23507178171384496, 'fraction_over_median_degree': 0.07486271116670501}
#
#  {'epoch': 550, 'bce_loss_kegg': 0.06677547097206116, 'bce_loss_reactome': 0.05206097662448883, 'bce_loss_wikipathways': 0.052963003516197205, 'bce_loss_biocarta': 0.07225427031517029, 'sum_bce_loss': 0.24405372142791748, 'accuracy_kegg': 0.9937604069709778, 'sensitivity_kegg': 0.014056225307285786, 'specificity_kegg': 0.9998502135276794, 'precision_kegg': 0.3684210479259491, 'f1_score_kegg': 0.027079302817583084, 'auprc_kegg': 0.3998264787228054, 'accuracy_reactome': 0.9973693490028381, 'sensitivity_reactome': 0.0022040302865207195, 'specificity_reactome': 0.9999949932098389, 'precision_reactome': 0.5384615659713745, 'f1_score_reactome': 0.004390091169625521, 'auprc_reactome': 0.46067539456113044, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.4831264517374641, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.4096245030083364, 'mean_accuracy': 0.9951610714197159, 'mean_sensitivity': 0.004065063898451626, 'mean_specificity': 0.9999613016843796, 'mean_precision': nan, 'mean_f1_score': 0.007867348496802151, 'mean_auprc': 0.4383132070074341, 'cosine_self_similarity_loss': 729.8863525390625, 'rmse_of_module_size_loss': 1157.0140380859375, 'thresholdOfCommunities': 0.5575917363166809, 'count': 23, 'average_size': 427.6521739130435, 'max_size': 3675, 'num_smaller_5': 19, 'num_smaller_10': 19, 'num_smaller_50': 19, 'num_smaller_100': 19, 'num_smaller_200': 20, 'node_coverage': 0.5976065345406193, 'mean_module_per_node': 0.6228075623512268, 'average_internal_degree': 5.904403266030497, 'conductance': 0.7349156913395867, 'internal_edge_density': 0.19894890360984066, 'fraction_over_median_degree': 0.10537188034363351}
#
#  {'epoch': 600, 'bce_loss_kegg': 0.060878556221723557, 'bce_loss_reactome': 0.04574845731258392, 'bce_loss_wikipathways': 0.0467301569879055, 'bce_loss_biocarta': 0.06707405298948288, 'sum_bce_loss': 0.22043122351169586, 'accuracy_kegg': 0.9937852025032043, 'sensitivity_kegg': 0.01606425642967224, 'specificity_kegg': 0.9998626708984375, 'precision_kegg': 0.42105263471603394, 'f1_score_kegg': 0.03094777651131153, 'auprc_kegg': 0.31808594331497786, 'accuracy_reactome': 0.9973759651184082, 'sensitivity_reactome': 0.004408060573041439, 'specificity_reactome': 0.9999958276748657, 'precision_reactome': 0.7368420958518982, 'f1_score_reactome': 0.008763693273067474, 'auprc_reactome': 0.43416661471690016, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.4498745862702717, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.33256067244753557, 'mean_accuracy': 0.995168924331665, 'mean_sensitivity': 0.00511807925067842, 'mean_specificity': 0.9999646246433258, 'mean_precision': nan, 'mean_f1_score': 0.009927867446094751, 'mean_auprc': 0.38367195418742134, 'cosine_self_similarity_loss': 718.1648559570312, 'rmse_of_module_size_loss': 897.9683227539062, 'thresholdOfCommunities': 0.5573791265487671, 'count': 37, 'average_size': 300.2162162162162, 'max_size': 3300, 'num_smaller_5': 27, 'num_smaller_10': 29, 'num_smaller_50': 32, 'num_smaller_100': 32, 'num_smaller_200': 32, 'node_coverage': 0.663395175077566, 'mean_module_per_node': 0.7033495306968689, 'average_internal_degree': 4.53611462628773, 'conductance': 0.7618644835004701, 'internal_edge_density': 0.2061844606177658, 'fraction_over_median_degree': 0.1380137098300655}
#
#  {'epoch': 650, 'bce_loss_kegg': 0.05582624301314354, 'bce_loss_reactome': 0.04050804674625397, 'bce_loss_wikipathways': 0.041601262986660004, 'bce_loss_biocarta': 0.06305460631847382, 'sum_bce_loss': 0.20099015906453133, 'accuracy_kegg': 0.9938844442367554, 'sensitivity_kegg': 0.02811245061457157, 'specificity_kegg': 0.9998876452445984, 'precision_kegg': 0.6086956262588501, 'f1_score_kegg': 0.05374280363321304, 'auprc_kegg': 0.20818190085777682, 'accuracy_reactome': 0.9973793029785156, 'sensitivity_reactome': 0.005037783179432154, 'specificity_reactome': 0.9999974966049194, 'precision_reactome': 0.8421052694320679, 'f1_score_reactome': 0.01001564972102642, 'auprc_reactome': 0.3929137313547618, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.41590960987627296, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.15608290199076727, 'mean_accuracy': 0.9951945692300797, 'mean_sensitivity': 0.008287558448500931, 'mean_specificity': 0.9999712854623795, 'mean_precision': nan, 'mean_f1_score': 0.015939613338559866, 'mean_auprc': 0.2932720360198947, 'cosine_self_similarity_loss': 693.2989501953125, 'rmse_of_module_size_loss': 673.748291015625, 'thresholdOfCommunities': 0.5570321679115295, 'count': 64, 'average_size': 205.0, 'max_size': 3137, 'num_smaller_5': 28, 'num_smaller_10': 38, 'num_smaller_50': 56, 'num_smaller_100': 56, 'num_smaller_200': 58, 'node_coverage': 0.7281073893497119, 'mean_module_per_node': 0.8307477235794067, 'average_internal_degree': 4.889023763925067, 'conductance': 0.6108054061251257, 'internal_edge_density': 0.2488527562058047, 'fraction_over_median_degree': 0.2398596981362315}
#
#  {'epoch': 700, 'bce_loss_kegg': 0.05158582702279091, 'bce_loss_reactome': 0.03620900213718414, 'bce_loss_wikipathways': 0.03739330917596817, 'bce_loss_biocarta': 0.06004209816455841, 'sum_bce_loss': 0.18523023650050163, 'accuracy_kegg': 0.9940953254699707, 'sensitivity_kegg': 0.05421686917543411, 'specificity_kegg': 0.9999375939369202, 'precision_kegg': 0.84375, 'f1_score_kegg': 0.1018867939710617, 'auprc_kegg': 0.1543176299823371, 'accuracy_reactome': 0.9973850846290588, 'sensitivity_reactome': 0.007241813465952873, 'specificity_reactome': 0.9999974966049194, 'precision_reactome': 0.8846153616905212, 'f1_score_reactome': 0.014366021379828453, 'auprc_reactome': 0.341235619814884, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.363389802871197, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.14464468996076058, 'mean_accuracy': 0.9952487349510193, 'mean_sensitivity': 0.015364670660346746, 'mean_specificity': 0.9999837726354599, 'mean_precision': nan, 'mean_f1_score': 0.02906320383772254, 'mean_auprc': 0.25089693565729465, 'cosine_self_similarity_loss': 669.552001953125, 'rmse_of_module_size_loss': 580.6416625976562, 'thresholdOfCommunities': 0.5564159750938416, 'count': 74, 'average_size': 191.52702702702703, 'max_size': 2420, 'num_smaller_5': 29, 'num_smaller_10': 33, 'num_smaller_50': 56, 'num_smaller_100': 62, 'num_smaller_200': 68, 'node_coverage': 0.7288672196542773, 'mean_module_per_node': 0.8974228501319885, 'average_internal_degree': 5.338365436832092, 'conductance': 0.6398592408828846, 'internal_edge_density': 0.1732462725260374, 'fraction_over_median_degree': 0.21761249026418855}
#
#  {'epoch': 750, 'bce_loss_kegg': 0.04855029284954071, 'bce_loss_reactome': 0.032683998346328735, 'bce_loss_wikipathways': 0.03398584946990013, 'bce_loss_biocarta': 0.05745624005794525, 'sum_bce_loss': 0.17267638072371483, 'accuracy_kegg': 0.9941201210021973, 'sensitivity_kegg': 0.06425702571868896, 'specificity_kegg': 0.9999001622200012, 'precision_kegg': 0.800000011920929, 'f1_score_kegg': 0.11895910650491714, 'auprc_kegg': 0.12951157809067573, 'accuracy_reactome': 0.9973809719085693, 'sensitivity_reactome': 0.008186398074030876, 'specificity_reactome': 0.9999908804893494, 'precision_reactome': 0.7027027010917664, 'f1_score_reactome': 0.016184251755475998, 'auprc_reactome': 0.28256545521641024, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.30028111313328265, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.13301998398052903, 'mean_accuracy': 0.9952539056539536, 'mean_sensitivity': 0.01811085594817996, 'mean_specificity': 0.9999727606773376, 'mean_precision': nan, 'mean_f1_score': 0.033785839565098286, 'mean_auprc': 0.2113445326052244, 'cosine_self_similarity_loss': 656.631591796875, 'rmse_of_module_size_loss': 467.8156433105469, 'thresholdOfCommunities': 0.5554628372192383, 'count': 111, 'average_size': 139.15315315315314, 'max_size': 2457, 'num_smaller_5': 59, 'num_smaller_10': 65, 'num_smaller_50': 79, 'num_smaller_100': 92, 'num_smaller_200': 104, 'node_coverage': 0.7349458620907997, 'mean_module_per_node': 0.9780281782150269, 'average_internal_degree': 4.083490861168791, 'conductance': 0.7305584971725285, 'internal_edge_density': 0.1533047680323966, 'fraction_over_median_degree': 0.19170634930133973}
#
#  {'epoch': 800, 'bce_loss_kegg': 0.04621843993663788, 'bce_loss_reactome': 0.03013729490339756, 'bce_loss_wikipathways': 0.0315273180603981, 'bce_loss_biocarta': 0.05525250360369682, 'sum_bce_loss': 0.16313555650413036, 'accuracy_kegg': 0.9941573143005371, 'sensitivity_kegg': 0.07630521804094315, 'specificity_kegg': 0.9998626708984375, 'precision_kegg': 0.7755101919174194, 'f1_score_kegg': 0.13893966376781464, 'auprc_kegg': 0.1011846797966154, 'accuracy_reactome': 0.9973676800727844, 'sensitivity_reactome': 0.011649874038994312, 'specificity_reactome': 0.999968409538269, 'precision_reactome': 0.4933333396911621, 'f1_score_reactome': 0.022762227803468704, 'auprc_reactome': 0.2537246020348427, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.2385223571287453, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.10706929480046645, 'mean_accuracy': 0.9952598810195923, 'mean_sensitivity': 0.021988773019984365, 'mean_specificity': 0.9999577701091766, 'mean_precision': nan, 'mean_f1_score': 0.040425472892820835, 'mean_auprc': 0.17512523344016748, 'cosine_self_similarity_loss': 654.2798461914062, 'rmse_of_module_size_loss': 504.75128173828125, 'thresholdOfCommunities': 0.5543929934501648, 'count': 85, 'average_size': 194.8, 'max_size': 2350, 'num_smaller_5': 24, 'num_smaller_10': 31, 'num_smaller_50': 49, 'num_smaller_100': 64, 'num_smaller_200': 74, 'node_coverage': 0.7569176217311467, 'mean_module_per_node': 1.0484391450881958, 'average_internal_degree': 6.673511505519284, 'conductance': 0.6199833081827735, 'internal_edge_density': 0.21611088749345103, 'fraction_over_median_degree': 0.27766926371953166}
#
#  {'epoch': 850, 'bce_loss_kegg': 0.04414677992463112, 'bce_loss_reactome': 0.02787143737077713, 'bce_loss_wikipathways': 0.02939010038971901, 'bce_loss_biocarta': 0.052789442241191864, 'sum_bce_loss': 0.15419775992631912, 'accuracy_kegg': 0.9941573143005371, 'sensitivity_kegg': 0.07630521804094315, 'specificity_kegg': 0.9998626708984375, 'precision_kegg': 0.7755101919174194, 'f1_score_kegg': 0.13893966376781464, 'auprc_kegg': 0.10596795734842916, 'accuracy_reactome': 0.9973801374435425, 'sensitivity_reactome': 0.015113350003957748, 'specificity_reactome': 0.9999717473983765, 'precision_reactome': 0.5853658318519592, 'f1_score_reactome': 0.02946593053638935, 'auprc_reactome': 0.21002692485195282, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.18949343625085138, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.15049880755972073, 'mean_accuracy': 0.9952629953622818, 'mean_sensitivity': 0.022854642011225224, 'mean_specificity': 0.9999586045742035, 'mean_precision': nan, 'mean_f1_score': 0.042101398576051, 'mean_auprc': 0.16399678150273853, 'cosine_self_similarity_loss': 646.9159545898438, 'rmse_of_module_size_loss': 448.41400146484375, 'thresholdOfCommunities': 0.5532496571540833, 'count': 99, 'average_size': 181.41414141414143, 'max_size': 2029, 'num_smaller_5': 32, 'num_smaller_10': 36, 'num_smaller_50': 58, 'num_smaller_100': 72, 'num_smaller_200': 87, 'node_coverage': 0.7937060723105173, 'mean_module_per_node': 1.1372126340866089, 'average_internal_degree': 6.1753056424956565, 'conductance': 0.6071116634080065, 'internal_edge_density': 0.20811978210693038, 'fraction_over_median_degree': 0.2992161139881649}
#
#  {'epoch': 900, 'bce_loss_kegg': 0.04216690734028816, 'bce_loss_reactome': 0.0259114820510149, 'bce_loss_wikipathways': 0.027530385181307793, 'bce_loss_biocarta': 0.04997918754816055, 'sum_bce_loss': 0.1455879621207714, 'accuracy_kegg': 0.994107723236084, 'sensitivity_kegg': 0.07630521804094315, 'specificity_kegg': 0.9998127818107605, 'precision_kegg': 0.7169811129570007, 'f1_score_kegg': 0.13793103396892548, 'auprc_kegg': 0.13960577777112582, 'accuracy_reactome': 0.9973734617233276, 'sensitivity_reactome': 0.017317380756139755, 'specificity_reactome': 0.9999592900276184, 'precision_reactome': 0.5288461446762085, 'f1_score_reactome': 0.03353658691048622, 'auprc_reactome': 0.16046896322587423, 'accuracy_wikipathways': 0.9971432685852051, 'sensitivity_wikipathways': 0.0, 'specificity_wikipathways': 1.0, 'precision_wikipathways': nan, 'f1_score_wikipathways': 0.0, 'auprc_wikipathways': 0.13254906853907358, 'accuracy_biocarta': 0.9923712611198425, 'sensitivity_biocarta': 0.0, 'specificity_biocarta': 1.0, 'precision_biocarta': nan, 'f1_score_biocarta': 0.0, 'auprc_biocarta': 0.2679970650906324, 'mean_accuracy': 0.9952489286661148, 'mean_sensitivity': 0.023405649699270725, 'mean_specificity': 0.9999430179595947, 'mean_precision': nan, 'mean_f1_score': 0.042866905219852924, 'mean_auprc': 0.17515521865667652, 'cosine_self_similarity_loss': 643.0195922851562, 'rmse_of_module_size_loss': 412.5792541503906, 'thresholdOfCommunities': 0.5501503944396973, 'count': 109, 'average_size': 174.47706422018348, 'max_size': 1909, 'num_smaller_5': 34, 'num_smaller_10': 42, 'num_smaller_50': 64, 'num_smaller_100': 82, 'num_smaller_200': 93, 'node_coverage': 0.8191603875134553, 'mean_module_per_node': 1.2042043209075928, 'average_internal_degree': 6.139795748314614, 'conductance': 0.6161890467747153, 'internal_edge_density': 0.1996486048588855, 'fraction_over_median_degree': 0.27259895236913356}
#
#  {'epoch': 950, 'bce_loss_kegg': 0.03977198153734207, 'bce_loss_reactome': 0.024146728217601776, 'bce_loss_wikipathways': 0.025819523259997368, 'bce_loss_biocarta': 0.04605558142066002, 'sum_bce_loss': 0.13579381443560123, 'accuracy_kegg': 0.9940829277038574, 'sensitivity_kegg': 0.09236947447061539, 'specificity_kegg': 0.9996879696846008, 'precision_kegg': 0.6478873491287231, 'f1_score_kegg': 0.16168716549873352, 'auprc_kegg': 0.1805265502671994, 'accuracy_reactome': 0.9973726868629456, 'sensitivity_reactome': 0.026763224974274635, 'specificity_reactome': 0.9999335408210754, 'precision_reactome': 0.5151515007019043, 'f1_score_reactome': 0.0508829690515995, 'auprc_reactome': 0.12534444299799025, 'accuracy_wikipathways': 0.9971457719802856, 'sensitivity_wikipathways': 0.0008650519303046167, 'specificity_wikipathways': 1.0, 'precision_wikipathways': 1.0, 'f1_score_wikipathways': 0.0017286085058003664, 'auprc_wikipathways': 0.09853139651386544, 'accuracy_biocarta': 0.9924088716506958, 'sensitivity_biocarta': 0.054187193512916565, 'specificity_biocarta': 0.9996213316917419, 'precision_biocarta': 0.523809552192688, 'f1_score_biocarta': 0.0982142835855484, 'auprc_biocarta': 0.345637197924097, 'mean_accuracy': 0.9952525645494461, 'mean_sensitivity': 0.0435462362220278, 'mean_specificity': 0.9998107105493546, 'mean_precision': 0.6717121005058289, 'mean_f1_score': 0.07812825666042045, 'mean_auprc': 0.187509896925788, 'cosine_self_similarity_loss': 624.919189453125, 'rmse_of_module_size_loss': 242.02940368652344, 'thresholdOfCommunities': 0.5425271987915039, 'count': 301, 'average_size': 72.734219269103, 'max_size': 1723, 'num_smaller_5': 209, 'num_smaller_10': 218, 'num_smaller_50': 247, 'num_smaller_100': 264, 'num_smaller_200': 278, 'node_coverage': 0.840372316849237, 'mean_module_per_node': 1.3862470388412476, 'average_internal_degree': 2.738938631690302, 'conductance': 0.839795689061137, 'internal_edge_density': 0.07715332284746752, 'fraction_over_median_degree': 0.12975014213917138}
#
#  {'epoch': 1000, 'bce_loss_kegg': 0.037127017974853516, 'bce_loss_reactome': 0.02251412719488144, 'bce_loss_wikipathways': 0.024169500917196274, 'bce_loss_biocarta': 0.0419757179915905, 'sum_bce_loss': 0.12578636407852173, 'accuracy_kegg': 0.9938844442367554, 'sensitivity_kegg': 0.13654617965221405, 'specificity_kegg': 0.9992136359214783, 'precision_kegg': 0.5190839767456055, 'f1_score_kegg': 0.21621622145175934, 'auprc_kegg': 0.20414160893400832, 'accuracy_reactome': 0.9973627328872681, 'sensitivity_reactome': 0.030226700007915497, 'specificity_reactome': 0.9999144077301025, 'precision_reactome': 0.48241207003593445, 'f1_score_reactome': 0.0568888895213604, 'auprc_reactome': 0.11042359415051413, 'accuracy_wikipathways': 0.9971482157707214, 'sensitivity_wikipathways': 0.019031140953302383, 'specificity_wikipathways': 0.9999504089355469, 'precision_wikipathways': 0.523809552192688, 'f1_score_wikipathways': 0.03672787919640541, 'auprc_wikipathways': 0.11374577025701908, 'accuracy_biocarta': 0.9928598403930664, 'sensitivity_biocarta': 0.13793103396892548, 'specificity_biocarta': 0.9994319677352905, 'precision_biocarta': 0.6511628031730652, 'f1_score_biocarta': 0.22764228284358978, 'auprc_biocarta': 0.4416652925580271, 'mean_accuracy': 0.9953138083219528, 'mean_sensitivity': 0.08093376364558935, 'mean_specificity': 0.9996276050806046, 'mean_precision': 0.5441171005368233, 'mean_f1_score': 0.13436881825327873, 'mean_auprc': 0.21749406647489217, 'cosine_self_similarity_loss': 588.998291015625, 'rmse_of_module_size_loss': 305.3729553222656, 'thresholdOfCommunities': 0.5247057676315308, 'count': 182, 'average_size': 131.5164835164835, 'max_size': 1693, 'num_smaller_5': 58, 'num_smaller_10': 82, 'num_smaller_50': 118, 'num_smaller_100': 140, 'num_smaller_200': 156, 'node_coverage': 0.8698790603431901, 'mean_module_per_node': 1.5156080722808838, 'average_internal_degree': 5.801134161489847, 'conductance': 0.692942464666088, 'internal_edge_density': 0.2741166685084088, 'fraction_over_median_degree': 0.2919066027071147}
#
#  {'epoch': 1050, 'bce_loss_kegg': 0.03516293317079544, 'bce_loss_reactome': 0.021191269159317017, 'bce_loss_wikipathways': 0.022892728447914124, 'bce_loss_biocarta': 0.039091866463422775, 'sum_bce_loss': 0.11833879724144936, 'accuracy_kegg': 0.9938099980354309, 'sensitivity_kegg': 0.1606425642967224, 'specificity_kegg': 0.9989889860153198, 'precision_kegg': 0.4968944191932678, 'f1_score_kegg': 0.24279211461544037, 'auprc_kegg': 0.24991861893661627, 'accuracy_reactome': 0.9973635673522949, 'sensitivity_reactome': 0.03935768082737923, 'specificity_reactome': 0.9998911619186401, 'precision_reactome': 0.48828125, 'f1_score_reactome': 0.07284381985664368, 'auprc_reactome': 0.13376426644117237, 'accuracy_wikipathways': 0.9971358776092529, 'sensitivity_wikipathways': 0.027681661769747734, 'specificity_wikipathways': 0.9999132752418518, 'precision_wikipathways': 0.4776119291782379, 'f1_score_wikipathways': 0.05233033373951912, 'auprc_wikipathways': 0.12555900292769334, 'accuracy_biocarta': 0.9934235215187073, 'sensitivity_biocarta': 0.2068965584039688, 'specificity_biocarta': 0.9994698166847229, 'precision_biocarta': 0.75, 'f1_score_biocarta': 0.3243243098258972, 'auprc_biocarta': 0.4579790331575207, 'mean_accuracy': 0.9954332411289215, 'mean_sensitivity': 0.10864461632445455, 'mean_specificity': 0.9995658099651337, 'mean_precision': 0.5531968995928764, 'mean_f1_score': 0.1730726445093751, 'mean_auprc': 0.24180523036575066, 'cosine_self_similarity_loss': 559.613525390625, 'rmse_of_module_size_loss': 189.71841430664062, 'thresholdOfCommunities': 0.5038428902626038, 'count': 468, 'average_size': 57.43162393162393, 'max_size': 1654, 'num_smaller_5': 313, 'num_smaller_10': 354, 'num_smaller_50': 397, 'num_smaller_100': 418, 'num_smaller_200': 433, 'node_coverage': 0.8886848603811816, 'mean_module_per_node': 1.7018930912017822, 'average_internal_degree': 2.7364257181152354, 'conductance': 0.8326573742948514, 'internal_edge_density': 0.15521743843752908, 'fraction_over_median_degree': 0.15497830672930832}
